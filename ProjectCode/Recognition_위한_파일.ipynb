# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Pip install method (recommended)
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.35 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.4/107.7 GB disk)

# %%
# Git clone method (for development)
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 4569, done.
# remote: Counting objects: 100% (204/204), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 4569 (delta 96), reused 123 (delta 47), pack-reused 4365
# Receiving objects: 100% (4569/4569), 4.07 MiB | 15.17 MiB/s, done.
# Resolving deltas: 100% (2973/2973), done.

# %%
from ultralytics import YOLO

# %%
model = YOLO("/content/best.pt")

# %%
import os

# %%
directory = '/content/drive/MyDrive/test/images/'

# %%
for i in os.listdir(directory):
    print(i)

# %%
from tqdm.notebook import tqdm

# %%
for i in tqdm(os.listdir(directory)):
    model.predict(source=directory+i, save_crop=True)
# Out:
#   0%|          | 0/700 [00:00<?, ?it/s]
# Ultralytics YOLOv8.0.35 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/utils/plotting.py:153: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xyxy = torch.tensor(xyxy).view(-1, 4)
# image 1/1 /content/drive/MyDrive/test/images/20230131_141308_jpg.rf.c2592b141ce3982e0947d350acd0535a.jpg: 1280x1280 1 trackingnumber, 1074.3ms
# Speed: 29.8ms pre-process, 1074.3ms inference, 27.3ms postprocess per image at shape (1, 3, 1280, 1280)
#
# image 1/1 /content/drive/MyDrive/test/images/20230131_141232_jpg.rf.66ec0f0c0048c44de54af3eb619a1f78.jpg: 1280x1280 1 trackingnumber, 874.3ms
# ...

# %%
import shutil

# %%
shutil.move('/content/runs/detect/predict/crops/trackingnumber','/content/drive/MyDrive')
# Out:
# '/content/drive/MyDrive/trackingnumber'

# %%
results = model("/content/drive/MyDrive/test/*.jpg", crop_save=True)
